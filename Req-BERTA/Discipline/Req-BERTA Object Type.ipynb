# %% [markdown]
# For colab

# %%
import os
import sys
from google.colab import drive

# Mount google drive.
drive.mount('/gdrive')

# !pip install simpletransformers
# !pip install wandb -qU

from simpletransformers.classification import ClassificationModel
import pandas as pd
import logging
import sklearn
import torch
import wandb

Colab=True
# Out:
# Mounted at /gdrive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.11-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2022.10.31)
# Collecting transformers>=4.6.0 (from simpletransformers)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 77.1 MB/s eta 0:00:00
# Collecting datasets (from simpletransformers)
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.2.2)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.5.3)
# Collecting tokenizers (from simpletransformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.2 MB/s eta 0:00:00
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.15.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.4 MB/s eta 0:00:00
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.22.0-py2.py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 80.4 MB/s eta 0:00:00
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers>=4.6.0->simpletransformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-1.23.1-py2.py3-none-any.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 25.2 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.10.32->simpletransformers)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.7 MB/s eta 0:00:00
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 28.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (2023.4.0)
# Collecting aiohttp (from datasets->simpletransformers)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 80.7 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets->simpletransformers)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Collecting blinker>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (5.3.0)
# Collecting importlib-metadata>=1.4 (from streamlit->simpletransformers)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.4.0)
# Collecting pympler>=0.9 (from streamlit->simpletransformers)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (13.3.4)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.2.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.5.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.3)
# Collecting validators>=0.2 (from streamlit->simpletransformers)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydeck>=0.1.dev5 (from streamlit->simpletransformers)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 84.2 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (6.3.1)
# Collecting watchdog (from streamlit->simpletransformers)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.40.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets->simpletransformers)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 23.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.15.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers) (2023.3)
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=dfb7f17c73beec2e9ddadfbec2d877af4185b3526d34c6d50ccca2c69ac959bd
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=d3ba34252de7bc2a7cc0e579119567a40a26b91cfc48aa73aeeb269e184be83b
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=67b8844a3aa95f3fba0bdc6ea3e38496cad8eed1f5fe0fcdd0a059bf60d49413
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built seqeval validators pathtools
# Installing collected packages: tokenizers, sentencepiece, pathtools, xxhash, watchdog, validators, smmap, setproctitle, sentry-sdk, pympler, multidict, importlib-metadata, frozenlist, docker-pycreds, dill, blinker, async-timeout, yarl, responses, pydeck, multiprocess, huggingface-hub, gitdb, aiosignal, transformers, seqeval, GitPython, aiohttp, wandb, streamlit, datasets, simpletransformers
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 blinker-1.6.2 datasets-2.12.0 dill-0.3.6 docker-pycreds-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 huggingface-hub-0.14.1 importlib-metadata-6.6.0 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 pydeck-0.8.1b0 pympler-1.0.1 responses-0.18.0 sentencepiece-0.1.99 sentry-sdk-1.23.1 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.11 smmap-5.0.0 streamlit-1.22.0 tokenizers-0.13.3 transformers-4.29.2 validators-0.20.0 wandb-0.15.3 watchdog-3.0.0 xxhash-3.2.0 yarl-1.9.2

# %% [markdown]
# wandb.login()

# %%
#Query the current cuda version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
#For Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset prep

# %% [markdown]
# Final Adjustments to the dataset before training. Some outputs are removed to protect Propriety information

# %%
pd.set_option('display.max_columns', None)
if Colab==False:
    train_df=pd.read_csv('path to/train_data.csv', encoding='ISO-8859-1')
    test_df=pd.read_csv('path to/test_data.csv', encoding='ISO-8859-1')
    val_df=pd.read_csv('path to/val_data.csv', encoding='ISO-8859-1')
if Colab==True:
    train_df=pd.read_csv('path to/train_data.csv', encoding='ISO-8859-1')
    test_df=pd.read_csv('path to/test_data.csv', encoding='ISO-8859-1')
    val_df=pd.read_csv('path to/val_data.csv', encoding='ISO-8859-1')

train_df.head()

# %%
train_df['Object Text'] = train_df['Object Text'].astype('str')
test_df['Object Text'] = test_df['Object Text'].astype('str')
val_df['Object Text'] = val_df['Object Text'].astype('str')

train_df_binary=train_df.drop(['Object Type','Module Name', 'Module UID', 'Requirement ID'],axis=1)
test_df_binary=test_df.drop(['Object Type','Module Name', 'Module UID', 'Requirement ID'],axis=1)
val_df_binary=val_df.drop(['Object Type','Module Name', 'Module UID', 'Requirement ID'],axis=1)

train_df_binary = train_df_binary.rename(columns={"Object Text": "text", "Discipline": "labels"})
test_df_binary = test_df_binary.rename(columns={"Object Text": "text", "Discipline": "labels"})
val_df_binary = val_df_binary.rename(columns={"Object Text": "text", "Discipline": "labels"})
train_df_binary.head()

# %%
train_df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9542 entries, 0 to 9541
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    9542 non-null   object
#  1   labels  9542 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 149.2+ KB

# %% [markdown]
# ## Configuring the model

# %%
sweep_config = {
    "method": "grid",  # grid, random, bayes
    "metric": {"name": 'eval_loss', "goal": 'minimize'},
    "parameters": {
        "optimizer": {"values": ['AdamW', 'Adafactor']},
        "train_batch_size" :{"values": [32, 8, 4]},
        "learning_rate": {"values": [4e-5, 1e-5]}
        #"learning_rate": {"min": 5e-5, "max": 4e-4},
    },
    "early_terminate" : {
        "type": "hyperband",
        "eta": 2,
        "min_iter":2
    }
}

sweep_id = wandb.sweep(sweep_config, project="DisciplineTypeRobertaV1.01")
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ERROR:wandb.sdk.internal.internal_api:500 response executing GraphQL.
# ERROR:wandb.sdk.internal.internal_api:{"errors":[{"message":"An internal error occurred. Please contact support.","path":["upsertSweep"]}],"data":{"upsertSweep":null}}
# wandb: ERROR Error while calling W&B API: An internal error occurred. Please contact support. (<Response [500]>)
# Create sweep with ID: yg79wvoc
# Sweep URL: https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc

# %%
binary_args={
    'output_dir':'/gdrive/MyDrive/Transformers/V2/Discipline/Checkpoints/', #where all outputs will be stored. This includes model checkpoints and evaluation results.
    'best_model_dir':'/gdrive/MyDrive/Transformers/V2/Discipline/BestModel/', #The directory where the best model (model checkpoints) will be saved (based on eval_during_training)
    'cache_dir': '/gdrive/MyDrive/Transformers/V2/Discipline/Cache/', #The directory where cached files will be saved.
    'tensorboard_dir': '/gdrive/MyDrive/Transformers/V2/Discipline/TensorBoard/', 
    'overwrite_output_dir': True, # trained model will be saved to the ouput_dir but will overwrite existing saved models in the same directory.
    'reprocess_input_data': True, # input data will be reprocessed even if a cached file of the input data exists in the cache_dir.
    'train_batch_size':32, #Larger batch sizes train faster but consume more memory and might show lower accuracy
    'eval_batch_size': 8, #Evaluation batch size
    'gradient_accumulation_steps':1, #The number of training steps to execute before performing a optimizer.step(). Effectively increases the training batch size while sacrificing training time to lower memory consumption.
    'learning_rate': 4e-5,#Lower LR increases accuracy but also increases training time.
    'adafactor_relative_step': True,# If True, time-dependent learning rate is computed instead of external learning rate.
    'num_train_epochs': 4, #3 passes through the training set
    'show_running_loss': True, #Log the loss to the console
    'max_seq_length': 128, #512 #Max number of input tokens
    'weight_decay': 0, #Prevents overfitting by penalizing large weights via adding the L2 penalty.
    'adam_epsilon': 1e-8, #Epsilon parameter used in AdamOptimizer. AdamOptimizer is the extended version of SGD.
    'warmup_ratio': 0.06, #Ratio of total training steps where learning rate will “warm up”.The learning rate is increased linearly over the warm-up period.
    'warmup_steps': 0,#Overrides warmup_ratio if not zero.
    'max_grad_norm': 1.0, #Maximum Gradient clipping. Avoids exploding gradients.
    'logging_steps': 1, #Log training loss and learning at every specified number of steps
    'evaluate_during_training': True, #perform evaluation while training model
    'save_steps': 500, #Save a model checkpoint at every specified number of steps
    'use_early_stopping' : True, #Use early stopping to stop training when early_stopping_metric doesn’t improve (based on early_stopping_patience, and early_stopping_delta)
    'early_stopping_metric': 'eval_loss', #Use validation loss as the early stopping metric
    'early_stopping_patience': 3, #Terminate training after this many evaluations without an improvement in the evaluation metric greater then early_stopping_delta.
    'early_stopping_delta': 0.005, #The improvement over best_eval_loss necessary to count as a better checkpoint.
    #'encoding': #Specify an encoding to be used when reading text files.
    'use_tensorboard': True,
    'optimizer': 'AdamW', #OR Adafactor
    'polynomial_decay_schedule_lr_end': 1e-7, #The end learning rate.
    'scheduler' : 'linear_schedule_with_warmup', #The scheduler to use when training. 
    'fp16': False, #fp16 mode requires NVidia Apex library. Can process up to 8 times faster than FP32 on modern GPUs and require less memory.
    'n_gpu': 1, #Number of GPUs to be used
    'wandb_project':'DisciplineTypeRobertaV1.01', #Name of W&B project. This will log all hyperparameter values, training losses, and evaluation metrics to the given project.
    'wandb_kwargs' :{'dir': '/gdrive/MyDrive/Transformers/V2/Discipline/WandB/' }
}

# %%
def train():
    wandb.init(dir='/gdrive/MyDrive/Transformers/V2/Discipline/WandB/')

    modelBinary = ClassificationModel('roberta', 'roberta-base', args=binary_args, use_cuda=True)

    modelBinary.train_model(train_df_binary,
                        output_dir='/gdrive/MyDrive/Transformers/V2/Discipline/Checkpoints/',
                        show_running_loss=True,
                        eval_df=val_df_binary,
                        verbose=True
                        )
    modelBinary.eval_model(val_df_binary)
    wandb.join()

wandb.agent(sweep_id, train, count=14) #Count should really be 12, since there are only 12 combinations. But wandb agent has a known bug of creating duplicates https://github.com/wandb/wandb/issues/3522
# Out:
# wandb: Agent Starting Run: x735ggh7 with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 32
# wandb: Currently logged in as: alanpaddy. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_112026-x735ggh7</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/x735ggh7' target="_blank">northern-sweep-1</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/x735ggh7' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/x735ggh7</a>
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>██▆▃▃▃▂▄▅▂▂▁▄▁▅▄▃▁▃▁▁▁▂▁▃▁▂▁▅▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>auprc</td><td>▁█▇█</td></tr><tr><td>auroc</td><td>▁▇▇█</td></tr><tr><td>eval_loss</td><td>█▁▇▇</td></tr><tr><td>fn</td><td>█▂▁▃</td></tr><tr><td>fp</td><td>▁▃█▂</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁█▇█</td></tr><tr><td>tn</td><td>█▆▁▇</td></tr><tr><td>tp</td><td>▁▇█▆</td></tr><tr><td>train_loss</td><td>█▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.0048</td></tr><tr><td>auprc</td><td>0.99895</td></tr><tr><td>auroc</td><td>0.99473</td></tr><tr><td>eval_loss</td><td>0.11732</td></tr><tr><td>fn</td><td>38</td></tr><tr><td>fp</td><td>20</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.91272</td></tr><tr><td>tn</td><td>368</td></tr><tr><td>tp</td><td>1960</td></tr><tr><td>train_loss</td><td>0.0048</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">northern-sweep-1</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/x735ggh7' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/x735ggh7</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_112026-x735ggh7/logs</code>
# wandb: Agent Starting Run: dgozlmf4 with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 8
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_112802-dgozlmf4</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/dgozlmf4' target="_blank">lemon-sweep-2</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/dgozlmf4' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/dgozlmf4</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▃▂▂▃▃▁▂▅▁▂▁▂▃▁▂▁▁▁▁▁▁▁▂▂▁▁▁▃▁▁▁▁▃▁▁▁▁▁</td></tr><tr><td>auprc</td><td>▂▆▁█</td></tr><tr><td>auroc</td><td>▁▆▆█</td></tr><tr><td>eval_loss</td><td>█▁▄▅</td></tr><tr><td>fn</td><td>█▃▁▂</td></tr><tr><td>fp</td><td>▁▆█▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▅▇█</td></tr><tr><td>tn</td><td>█▃▁█</td></tr><tr><td>tp</td><td>▁▆█▇</td></tr><tr><td>train_loss</td><td>█▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00074</td></tr><tr><td>auprc</td><td>0.99918</td></tr><tr><td>auroc</td><td>0.99578</td></tr><tr><td>eval_loss</td><td>0.10015</td></tr><tr><td>fn</td><td>22</td></tr><tr><td>fp</td><td>23</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.93068</td></tr><tr><td>tn</td><td>365</td></tr><tr><td>tp</td><td>1976</td></tr><tr><td>train_loss</td><td>0.00074</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lemon-sweep-2</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/dgozlmf4' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/dgozlmf4</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_112802-dgozlmf4/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 61kpzhsa with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 4
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_113531-61kpzhsa</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/61kpzhsa' target="_blank">spring-sweep-3</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/61kpzhsa' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/61kpzhsa</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▄▃▂▃▃▅▄▂▃▁▁▂▂▃▁▂▃▁▂▁▁▁▁▁▁▃▃▁▄▁▁▂▁▁▃▁▁▁▁</td></tr><tr><td>auprc</td><td>▁▆▇█</td></tr><tr><td>auroc</td><td>▁▆▇█</td></tr><tr><td>eval_loss</td><td>█▁▃▂</td></tr><tr><td>fn</td><td>█▂▁▃</td></tr><tr><td>fp</td><td>█▄▄▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▆▆█</td></tr><tr><td>tn</td><td>▁▅▅█</td></tr><tr><td>tp</td><td>▁▇█▆</td></tr><tr><td>train_loss</td><td>▂█▇▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00036</td></tr><tr><td>auprc</td><td>0.99929</td></tr><tr><td>auroc</td><td>0.9963</td></tr><tr><td>eval_loss</td><td>0.08157</td></tr><tr><td>fn</td><td>31</td></tr><tr><td>fp</td><td>13</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.93388</td></tr><tr><td>tn</td><td>375</td></tr><tr><td>tp</td><td>1967</td></tr><tr><td>train_loss</td><td>0.00036</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">spring-sweep-3</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/61kpzhsa' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/61kpzhsa</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_113531-61kpzhsa/logs</code>
# wandb: Agent Starting Run: xohg23a6 with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 32
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_114255-xohg23a6</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/xohg23a6' target="_blank">fiery-sweep-4</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/xohg23a6' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/xohg23a6</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.010 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.115107…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▄▄▂▆▃▄▂▃▂▂▁▁▂▂▃▃▂▂▁▄▃▁▂▁▃▂▁▁▁▁▂▁▂▁▁▁▂▁</td></tr><tr><td>auprc</td><td>▁█</td></tr><tr><td>auroc</td><td>▁█</td></tr><tr><td>eval_loss</td><td>▁█</td></tr><tr><td>fn</td><td>▁█</td></tr><tr><td>fp</td><td>█▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▃▅▇████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▃▃▃</td></tr><tr><td>mcc</td><td>█▁</td></tr><tr><td>tn</td><td>▁█</td></tr><tr><td>tp</td><td>█▁</td></tr><tr><td>train_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00412</td></tr><tr><td>auprc</td><td>0.99845</td></tr><tr><td>auroc</td><td>0.99165</td></tr><tr><td>eval_loss</td><td>0.14188</td></tr><tr><td>fn</td><td>74</td></tr><tr><td>fp</td><td>12</td></tr><tr><td>global_step</td><td>777</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>mcc</td><td>0.8792</td></tr><tr><td>tn</td><td>376</td></tr><tr><td>tp</td><td>1924</td></tr><tr><td>train_loss</td><td>0.00061</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fiery-sweep-4</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/xohg23a6' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/xohg23a6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_114255-xohg23a6/logs</code>
# wandb: Agent Starting Run: kbmy3ahi with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 8
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_114734-kbmy3ahi</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/kbmy3ahi' target="_blank">restful-sweep-5</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/kbmy3ahi' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/kbmy3ahi</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▄▅▃▂▂▂▂▂▄▂▁▁▃▁▂▁▃▂▁▁▂▃▁▁▆▃▁▁▁▂▁▁▁▁▂▁▁▁</td></tr><tr><td>auprc</td><td>▁▄██</td></tr><tr><td>auroc</td><td>▁▅██</td></tr><tr><td>eval_loss</td><td>█▁▄▅</td></tr><tr><td>fn</td><td>▁█▁▃</td></tr><tr><td>fp</td><td>█▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▆█▇</td></tr><tr><td>tn</td><td>▁███</td></tr><tr><td>tp</td><td>█▁█▆</td></tr><tr><td>train_loss</td><td>▃█▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00048</td></tr><tr><td>auprc</td><td>0.99904</td></tr><tr><td>auroc</td><td>0.99518</td></tr><tr><td>eval_loss</td><td>0.09831</td></tr><tr><td>fn</td><td>25</td></tr><tr><td>fp</td><td>26</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.92144</td></tr><tr><td>tn</td><td>362</td></tr><tr><td>tp</td><td>1973</td></tr><tr><td>train_loss</td><td>0.00048</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">restful-sweep-5</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/kbmy3ahi' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/kbmy3ahi</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_114734-kbmy3ahi/logs</code>
# wandb: Agent Starting Run: a91m6rwi with config:
# wandb: 	learning_rate: 4e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 4
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_115516-a91m6rwi</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/a91m6rwi' target="_blank">elated-sweep-6</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/a91m6rwi' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/a91m6rwi</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▃▃▃▂▃▃▃▃▂▁▂▃▃▃▁▁▁▁▃▁▁▃▂▂▁▂▂▁▁▁▁▁▁▁▁▃▁▁</td></tr><tr><td>auprc</td><td>▁▅▆█</td></tr><tr><td>auroc</td><td>▁▅▆█</td></tr><tr><td>eval_loss</td><td>█▂▁▂</td></tr><tr><td>fn</td><td>█▁▁▂</td></tr><tr><td>fp</td><td>▁█▅▃</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▆▇█</td></tr><tr><td>tn</td><td>█▁▄▆</td></tr><tr><td>tp</td><td>▁██▇</td></tr><tr><td>train_loss</td><td>▇█▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00281</td></tr><tr><td>auprc</td><td>0.99905</td></tr><tr><td>auroc</td><td>0.99519</td></tr><tr><td>eval_loss</td><td>0.0966</td></tr><tr><td>fn</td><td>29</td></tr><tr><td>fp</td><td>18</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.92862</td></tr><tr><td>tn</td><td>370</td></tr><tr><td>tp</td><td>1969</td></tr><tr><td>train_loss</td><td>0.00281</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-6</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/a91m6rwi' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/a91m6rwi</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_115516-a91m6rwi/logs</code>
# wandb: Agent Starting Run: 05qqvqa0 with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 32
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_120359-05qqvqa0</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/05qqvqa0' target="_blank">balmy-sweep-7</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/05qqvqa0' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/05qqvqa0</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▅▆▃▃▄▄▄▂▃▅▃▁▁▄▂▁▄▃▁▁▂▁▅▁▁▃▁▁▁▃▂▁▁▁▂▁▂▁▁</td></tr><tr><td>auprc</td><td>█▁</td></tr><tr><td>auroc</td><td>█▁</td></tr><tr><td>eval_loss</td><td>█▁</td></tr><tr><td>fn</td><td>▁█</td></tr><tr><td>fp</td><td>█▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▃▅▇████▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▃</td></tr><tr><td>mcc</td><td>▁█</td></tr><tr><td>tn</td><td>▁█</td></tr><tr><td>tp</td><td>█▁</td></tr><tr><td>train_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.1411</td></tr><tr><td>auprc</td><td>0.99091</td></tr><tr><td>auroc</td><td>0.97706</td></tr><tr><td>eval_loss</td><td>0.12554</td></tr><tr><td>fn</td><td>24</td></tr><tr><td>fp</td><td>49</td></tr><tr><td>global_step</td><td>740</td></tr><tr><td>lr</td><td>2e-05</td></tr><tr><td>mcc</td><td>0.88536</td></tr><tr><td>tn</td><td>339</td></tr><tr><td>tp</td><td>1974</td></tr><tr><td>train_loss</td><td>0.01308</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">balmy-sweep-7</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/05qqvqa0' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/05qqvqa0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_120359-05qqvqa0/logs</code>
# wandb: Agent Starting Run: pkzj0oow with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 8
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_120837-pkzj0oow</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/pkzj0oow' target="_blank">comfy-sweep-8</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/pkzj0oow' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/pkzj0oow</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▅▃▃▁▄▂▅▂▅▂▂▄▃▂▃▂▁▄▃▃▁▁▂▃▂▁▃▄▁▂▃▃▁▁▃▁▁▁▃</td></tr><tr><td>auprc</td><td>▁█</td></tr><tr><td>auroc</td><td>▁█</td></tr><tr><td>eval_loss</td><td>█▁</td></tr><tr><td>fn</td><td>▁█</td></tr><tr><td>fp</td><td>█▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>lr</td><td>▁▃▅▆████▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▃</td></tr><tr><td>mcc</td><td>▁█</td></tr><tr><td>tn</td><td>▁█</td></tr><tr><td>tp</td><td>█▁</td></tr><tr><td>train_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.25655</td></tr><tr><td>auprc</td><td>0.99892</td></tr><tr><td>auroc</td><td>0.99429</td></tr><tr><td>eval_loss</td><td>0.09705</td></tr><tr><td>fn</td><td>49</td></tr><tr><td>fp</td><td>18</td></tr><tr><td>global_step</td><td>733</td></tr><tr><td>lr</td><td>2e-05</td></tr><tr><td>mcc</td><td>0.90107</td></tr><tr><td>tn</td><td>370</td></tr><tr><td>tp</td><td>1949</td></tr><tr><td>train_loss</td><td>0.00286</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comfy-sweep-8</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/pkzj0oow' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/pkzj0oow</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_120837-pkzj0oow/logs</code>
# wandb: Agent Starting Run: vbgsfvkg with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: AdamW
# wandb: 	train_batch_size: 4
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_121341-vbgsfvkg</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/vbgsfvkg' target="_blank">elated-sweep-9</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/vbgsfvkg' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/vbgsfvkg</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▄▂▂▁▂▃▂▂▁▁▂▄▁▃▂▂▁▁▂▁▁▄▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>auprc</td><td>▁█▅▆</td></tr><tr><td>auroc</td><td>▁█▅▆</td></tr><tr><td>eval_loss</td><td>▇▂▁█</td></tr><tr><td>fn</td><td>█▂▁▁</td></tr><tr><td>fp</td><td>▁▅▇█</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁███</td></tr><tr><td>tn</td><td>█▄▂▁</td></tr><tr><td>tp</td><td>▁▇██</td></tr><tr><td>train_loss</td><td>▆▆█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00202</td></tr><tr><td>auprc</td><td>0.99897</td></tr><tr><td>auroc</td><td>0.99468</td></tr><tr><td>eval_loss</td><td>0.10008</td></tr><tr><td>fn</td><td>29</td></tr><tr><td>fp</td><td>24</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.91889</td></tr><tr><td>tn</td><td>364</td></tr><tr><td>tp</td><td>1969</td></tr><tr><td>train_loss</td><td>0.00202</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-9</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/vbgsfvkg' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/vbgsfvkg</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_121341-vbgsfvkg/logs</code>
# wandb: Agent Starting Run: 1jn2m1j6 with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 32
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_122221-1jn2m1j6</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/1jn2m1j6' target="_blank">stellar-sweep-10</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/1jn2m1j6' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/1jn2m1j6</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.010 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.115180…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>▇▆█▃▅▂▂▂▃▄▂▂▃▂▁▂▂▁▂▂▁▃▁▂▁▅▃▁▁▁▂▂▂▁▁▃▁▁▁▁</td></tr><tr><td>auprc</td><td>▁█</td></tr><tr><td>auroc</td><td>▁█</td></tr><tr><td>eval_loss</td><td>█▁</td></tr><tr><td>fn</td><td>█▁</td></tr><tr><td>fp</td><td>█▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▃▅▇████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃</td></tr><tr><td>mcc</td><td>▁█</td></tr><tr><td>tn</td><td>▁█</td></tr><tr><td>tp</td><td>▁█</td></tr><tr><td>train_loss</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00369</td></tr><tr><td>auprc</td><td>0.9992</td></tr><tr><td>auroc</td><td>0.99574</td></tr><tr><td>eval_loss</td><td>0.10225</td></tr><tr><td>fn</td><td>52</td></tr><tr><td>fp</td><td>11</td></tr><tr><td>global_step</td><td>784</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>mcc</td><td>0.90867</td></tr><tr><td>tn</td><td>377</td></tr><tr><td>tp</td><td>1946</td></tr><tr><td>train_loss</td><td>0.00479</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-10</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/1jn2m1j6' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/1jn2m1j6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_122221-1jn2m1j6/logs</code>
# wandb: Agent Starting Run: frtqiobv with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 8
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_122743-frtqiobv</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/frtqiobv' target="_blank">treasured-sweep-11</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/frtqiobv' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/frtqiobv</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>▆█▃▂▂▃▃▂▄▂▂▁▁▄▂▁▂▁▁▂▁▂▂▁▁▁▁▂▁▂▁▁▂▁▂▁▁▂▂▁</td></tr><tr><td>auprc</td><td>▁▇██</td></tr><tr><td>auroc</td><td>▁▇██</td></tr><tr><td>eval_loss</td><td>▇▁█▆</td></tr><tr><td>fn</td><td>▇██▁</td></tr><tr><td>fp</td><td>█▁▃▂</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▃▄▇███▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>mcc</td><td>▁▇▅█</td></tr><tr><td>tn</td><td>▁█▆▇</td></tr><tr><td>tp</td><td>▂▁▁█</td></tr><tr><td>train_loss</td><td>▂█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.00173</td></tr><tr><td>auprc</td><td>0.99921</td></tr><tr><td>auroc</td><td>0.99585</td></tr><tr><td>eval_loss</td><td>0.08349</td></tr><tr><td>fn</td><td>27</td></tr><tr><td>fp</td><td>21</td></tr><tr><td>global_step</td><td>1196</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>mcc</td><td>0.92663</td></tr><tr><td>tn</td><td>367</td></tr><tr><td>tp</td><td>1971</td></tr><tr><td>train_loss</td><td>0.00173</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">treasured-sweep-11</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/frtqiobv' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/frtqiobv</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_122743-frtqiobv/logs</code>
# wandb: Agent Starting Run: 87ttso05 with config:
# wandb: 	learning_rate: 1e-05
# wandb: 	optimizer: Adafactor
# wandb: 	train_batch_size: 4
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_123653-87ttso05</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05' target="_blank">sweepy-sweep-12</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05</a>
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/9542 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
#   0%|          | 0/2386 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/299 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.011 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.103533…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>█▆▄▃▂▃▄▂▂▃▂▁▁▂▃▃▃▁▄▁▁▂▁▄▁▁▁▂▂▃▁▃▁▁▁▁▂▁▁▁</td></tr><tr><td>auprc</td><td>▁█</td></tr><tr><td>auroc</td><td>▁█</td></tr><tr><td>eval_loss</td><td>█▁</td></tr><tr><td>fn</td><td>▁█</td></tr><tr><td>fp</td><td>█▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▃▅▇████▇▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃</td></tr><tr><td>mcc</td><td>▁█</td></tr><tr><td>tn</td><td>▁█</td></tr><tr><td>tp</td><td>█▁</td></tr><tr><td>train_loss</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Training loss</td><td>0.15991</td></tr><tr><td>auprc</td><td>0.99853</td></tr><tr><td>auroc</td><td>0.99276</td></tr><tr><td>eval_loss</td><td>0.09721</td></tr><tr><td>fn</td><td>46</td></tr><tr><td>fp</td><td>25</td></tr><tr><td>global_step</td><td>831</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>mcc</td><td>0.89352</td></tr><tr><td>tn</td><td>363</td></tr><tr><td>tp</td><td>1952</td></tr><tr><td>train_loss</td><td>0.01428</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweepy-sweep-12</strong> at: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/gdrive/MyDrive/Transformers/V2/Discipline/WandB/wandb/run-20230519_123653-87ttso05/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %%
modelBinaryTrained= ClassificationModel('roberta', '/gdrive/MyDrive/Transformers/V2/Discipline/BestModel/')
wandb.init() 
result, model_outputs, wrong_predictions = modelBinaryTrained.eval_model(test_df_binary,
                                                            output_dir='/gdrive/MyDrive/Transformers/V2/Discipline/Results/',
                                                            verbose=True)
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.15.3
# Run data is saved locally in <code>/content/wandb/run-20230519_124830-87ttso05</code>
# Syncing run <strong><a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05' target="_blank">sweepy-sweep-12</a></strong> to <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View project at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01</a>
#  View sweep at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/sweeps/yg79wvoc</a>
#  View run at <a href='https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05' target="_blank">https://wandb.ai/alanpaddy/DisciplineTypeRobertaV1.01/runs/87ttso05</a>
#   0%|          | 0/2983 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/373 [00:00<?, ?it/s]
